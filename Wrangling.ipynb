# %%
# Manipulation
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
exo2 = pd.read_csv('Data/exoplanet_data.csv')

# %%
exo2.sample(5)
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 2038  FALSE POSITIVE              0              0              0
# 4860  FALSE POSITIVE              1              0              0
# 6097  FALSE POSITIVE              0              1              0
# 2522       CANDIDATE              0              0              0
# 1919  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 2038              1    1.332570     1.330000e-05    -1.330000e-05
# 4860              0   40.038961     4.144000e-04    -4.144000e-04
# 6097              0    5.088408     2.140000e-07    -2.140000e-07
# 2522              0    4.034914     2.550000e-06    -2.550000e-06
# 1919              0   36.005441     3.175000e-04    -3.175000e-04
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 2038   132.038350          0.009560  ...            -199      4.571
# ...

# %%
exo2.shape
# Out:
# (6991, 41)

# %%
exo2.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %%
ax = sns.countplot(exo2['koi_disposition'])

# %%
values = exo2.drop(['koi_disposition'], axis=1)

# %%
fig = plt.figure(figsize=(15, 12))

for i in range(1, len(values.columns)):
    plt.subplot(6, 8, i)
    f = plt.gca()
    f.axes.get_yaxis().set_visible(False)

    vals = np.size(values.iloc[:, i].unique())
    if vals < 10:
        bins = vals
    else:
        vals = 10

    plt.hist(values.iloc[:, i], bins=10, color='#3F5D7D')
    plt.xlabel(values.columns[i])

plt.tight_layout()

# %%
exo2.describe()
# Out:
#        koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# count    6991.000000    6991.000000    6991.000000    6991.000000
# mean        0.157059       0.244743       0.202975       0.125018
# std         0.363882       0.429966       0.402243       0.330763
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#         koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# count  6991.000000     6.991000e+03     6.991000e+03  6991.000000
# mean     56.191248     1.851122e-03    -1.851122e-03   164.488820
# std     117.570962     7.184503e-03     7.184503e-03    67.020475
# min       0.259820     1.100000e-08    -1.568000e-01   120.515914
# ...

# %%
skip_columns = [
    'koi_disposition',
    'koi_fpflag_nt',
    'koi_fpflag_ss',
    'koi_fpflag_co',
    'koi_fpflag_ec'
]

to_drop = [
    'log_koi_period_err2', 
    'log_koi_time0bk_err2', 
    'log_koi_impact_err2',
    'log_koi_duration_err2',
    'log_koi_depth_err2',
    'log_koi_prad_err2',
    'log_koi_insol_err2',
    'log_koi_steff_err2',
    'log_koi_slogg_err2'#,
#     'log_koi_srad_err2',
#     'sq_koi_period_err2', 
#     'sq_koi_time0bk_err2', 
#     'sq_koi_impact_err2',
#     'sq_koi_duration_err2',
#     'sq_koi_depth_err2',
#     'sq_koi_prad_err2',
#     'sq_koi_insol_err2',
#     'sq_koi_steff_err2',
#     'sq_koi_slogg_err2',
#     'sq_koi_srad_err2' 
]

length = 0
trans_data = pd.DataFrame()

for (col, data) in exo2.items():
    
    log_label = 'log_' + str(col)
    sq_label = 'sq_' + str(col)
    
    if col in skip_columns:
        continue    
        
    elif data.min() == 0:   
        trans_data[log_label] = np.log(exo2[col] + 0.001)
        #trans_data[sq_label] = np.square(trans_data[log_label])
        
    elif data.max() == 0:
        trans_data[log_label] = np.log(np.absolute(exo2[col] + 0.001))
        #trans_data[sq_label] = np.square(trans_data[log_label])
        
    else:
        trans_data[log_label] = np.log(exo2[col])
        #trans_data[sq_label] = np.square(trans_data[log_label])
                        
trans_data = trans_data.drop(columns=to_drop)
# Out:
# C:\Users\TPCal\Anaconda3\lib\site-packages\ipykernel_launcher.py:52: RuntimeWarning: invalid value encountered in log
# C:\Users\TPCal\Anaconda3\lib\site-packages\ipykernel_launcher.py:48: RuntimeWarning: divide by zero encountered in log

# %%
trans_data.describe()
# Out:
#        log_koi_period  log_koi_period_err1  log_koi_time0bk  \
# count     6991.000000          6991.000000      6991.000000
# mean         2.375521           -10.150216         5.053087
# std          1.838856             3.009524         0.281656
# min         -1.347768           -18.325371         4.791782
# 25%          0.963222           -12.205074         4.887970
# 50%          2.191366           -10.319003         4.918076
# 75%          3.534638            -8.334456         5.135428
# max          6.976565            -1.852784         7.294732
#
#        log_koi_time0bk_err1  log_koi_impact  log_koi_impact_err1  \
# count           6991.000000     6991.000000          6991.000000
# mean              -5.843598       -1.082442            -1.974148
# std                1.795545        1.387444             1.930213
# min              -11.652188       -6.907755            -6.907755
# 25%               -6.772360       -1.614450            -3.196628
# ...

# %%
fig = plt.figure(figsize=(15, 12))

for i in range(1, len(trans_data.columns)):
    plt.subplot(9, 9, i)

    vals = np.size(trans_data.iloc[:, i].unique())
    
    if vals < 10:
        bins = vals
    else:
        vals = 10

    plt.hist(trans_data.iloc[:, i], bins=20, color='#3F5D7D')
    plt.xlabel(trans_data.columns[i])

plt.tight_layout()

# %%
fig = plt.figure(figsize=(15,60))

for i in range(1, len(trans_data.columns)):
    
    plt.subplot(20, 5, i)

    ax = sns.boxplot(exo2['koi_disposition'], trans_data.iloc[:, i])
    plt.xticks(rotation = 45)     

plt.tight_layout()

# %%
exo2 = pd.concat([exo2, trans_data], axis=1)
exo2.to_csv('transformed_features.csv')

# %%
corr = exo2.corr()

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, cmap=cmap, vmax=.3, center=0, square=True,
           linewidths=.5, cbar_kws={'shrink': .5})
