# %% [markdown]
# ## Dependencies

# %%
# Manipulation
import numpy as np
import pandas as pd
from scipy.stats import zscore

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load and Examine Data

# %%
exo2 = pd.read_csv('Data/exoplanet_data.csv')

# %%
exo2.sample(5)
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 2423       CONFIRMED              0              0              0
# 5913  FALSE POSITIVE              0              1              0
# 5393  FALSE POSITIVE              0              1              0
# 5861  FALSE POSITIVE              1              0              0
# 6428  FALSE POSITIVE              0              1              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 2423              0    4.166966     4.070000e-06    -4.070000e-06
# 5913              0    2.659419     8.900000e-08    -8.900000e-08
# 5393              0    0.790046     4.940000e-06    -4.940000e-06
# 5861              1    1.519452     3.430000e-05    -3.430000e-05
# 6428              0   26.951238     4.550000e-06    -4.550000e-06
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 2423   169.715517          0.000744  ...             -81      4.450
# 5913   133.320818          0.000028  ...            -202      4.500
# 5393   132.122500          0.007710  ...            -283      4.321
# 5861   132.597500          0.022900  ...             -86      4.250
# 6428   150.923211          0.000126  ...            -200      3.748
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 2423           0.072          -0.096     0.943          0.115         -0.077
# 5913           0.052          -0.208     0.932          0.272         -0.091
# 5393           0.058          -0.232     1.342          0.502         -0.167
# 5861           0.125          -0.125     1.307          0.230         -0.188
# 6428           0.285          -0.095     2.747          0.489         -0.908
#
#              ra        dec  koi_kepmag
# 2423  296.77191  41.755539      14.883
# 5913  293.84140  42.948139      14.905
# 5393  292.53986  41.211590      14.838
# 5861  290.46780  40.754238      12.585
# 6428  293.82971  40.031189      11.957
#
# [5 rows x 41 columns]

# %%
exo2.shape
# Out:
# (6991, 41)

# %%
exo2.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %%
ax = sns.countplot(exo2['koi_disposition'])

# %%
values = exo2.drop(['koi_disposition'], axis=1)

# %%
fig = plt.figure(figsize=(15, 12))

for i in range(1, len(values.columns)):
    plt.subplot(6, 8, i)
    f = plt.gca()
    f.axes.get_yaxis().set_visible(False)

    vals = np.size(values.iloc[:, i].unique())
    if vals < 10:
        bins = vals
    else:
        vals = 10

    plt.hist(values.iloc[:, i], bins=25, color='#3F5D7D')
    plt.xlabel(values.columns[i])

plt.tight_layout()

# %%
exo2.describe()
# Out:
#        koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# count    6991.000000    6991.000000    6991.000000    6991.000000
# mean        0.157059       0.244743       0.202975       0.125018
# std         0.363882       0.429966       0.402243       0.330763
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#         koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# count  6991.000000     6.991000e+03     6.991000e+03  6991.000000
# mean     56.191248     1.851122e-03    -1.851122e-03   164.488820
# std     117.570962     7.184503e-03     7.184503e-03    67.020475
# min       0.259820     1.100000e-08    -1.568000e-01   120.515914
# 25%       2.620126     5.005000e-06    -2.401000e-04   132.683917
# 50%       8.947426     3.300000e-05    -3.300000e-05   136.739230
# 75%      34.282605     2.401000e-04    -5.005000e-06   169.937005
# max    1071.232624     1.568000e-01    -1.100000e-08  1472.522306
#
#        koi_time0bk_err1  koi_time0bk_err2  ...  koi_steff_err2    koi_slogg  \
# count       6991.000000       6991.000000  ...     6991.000000  6991.000000
# mean           0.009340         -0.009340  ...     -161.206980     4.305049
# std            0.021989          0.021989  ...       71.448481     0.439238
# min            0.000009         -0.569000  ...    -1733.000000     0.047000
# 25%            0.001145         -0.010000  ...     -197.000000     4.209000
# 50%            0.003990         -0.003990  ...     -159.000000     4.436000
# 75%            0.010000         -0.001145  ...     -112.000000     4.543000
# max            0.569000         -0.000009  ...        0.000000     5.364000
#
#        koi_slogg_err1  koi_slogg_err2     koi_srad  koi_srad_err1  \
# count     6991.000000      6991.00000  6991.000000    6991.000000
# mean         0.121091        -0.14048     1.740749       0.352710
# std          0.132048         0.08199     5.903415       0.839017
# min          0.000000        -1.00700     0.109000       0.000000
# 25%          0.044000        -0.19500     0.829000       0.128000
# 50%          0.070000        -0.12700     0.999000       0.248000
# 75%          0.149000        -0.08800     1.357000       0.357000
# max          1.472000         0.00000   180.013000      25.956000
#
#        koi_srad_err2           ra          dec   koi_kepmag
# count    6991.000000  6991.000000  6991.000000  6991.000000
# mean       -0.388568   292.082406    43.812143    14.271508
# std         1.907797     4.762908     3.606167     1.350802
# min      -103.825000   279.856080    36.577381     6.966000
# 25%        -0.252000   288.704730    40.797760    13.455000
# 50%        -0.111000   292.314760    43.679661    14.534000
# 75%        -0.069000   295.888550    46.693659    15.322000
# max         0.000000   301.720760    52.336010    19.065000
#
# [8 rows x 40 columns]

# %%
fig = plt.figure(figsize=(15,60))

for i in range(1, len(exo2.columns)):
    
    plt.subplot(20, 5, i)

    ax = sns.boxplot(exo2['koi_disposition'], exo2.iloc[:, i])
    plt.xticks(rotation = 45)     

plt.tight_layout()

# %%
exo2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6991 entries, 0 to 6990
# Data columns (total 41 columns):
# koi_disposition      6991 non-null object
# koi_fpflag_nt        6991 non-null int64
# koi_fpflag_ss        6991 non-null int64
# koi_fpflag_co        6991 non-null int64
# koi_fpflag_ec        6991 non-null int64
# koi_period           6991 non-null float64
# koi_period_err1      6991 non-null float64
# koi_period_err2      6991 non-null float64
# koi_time0bk          6991 non-null float64
# koi_time0bk_err1     6991 non-null float64
# koi_time0bk_err2     6991 non-null float64
# koi_impact           6991 non-null float64
# koi_impact_err1      6991 non-null float64
# koi_impact_err2      6991 non-null float64
# koi_duration         6991 non-null float64
# koi_duration_err1    6991 non-null float64
# koi_duration_err2    6991 non-null float64
# koi_depth            6991 non-null float64
# koi_depth_err1       6991 non-null float64
# koi_depth_err2       6991 non-null float64
# koi_prad             6991 non-null float64
# koi_prad_err1        6991 non-null float64
# koi_prad_err2        6991 non-null float64
# koi_teq              6991 non-null int64
# koi_insol            6991 non-null float64
# koi_insol_err1       6991 non-null float64
# koi_insol_err2       6991 non-null float64
# koi_model_snr        6991 non-null float64
# koi_tce_plnt_num     6991 non-null int64
# koi_steff            6991 non-null int64
# koi_steff_err1       6991 non-null int64
# koi_steff_err2       6991 non-null int64
# koi_slogg            6991 non-null float64
# koi_slogg_err1       6991 non-null float64
# koi_slogg_err2       6991 non-null float64
# koi_srad             6991 non-null float64
# koi_srad_err1        6991 non-null float64
# koi_srad_err2        6991 non-null float64
# ra                   6991 non-null float64
# dec                  6991 non-null float64
# koi_kepmag           6991 non-null float64
# dtypes: float64(31), int64(9), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# ## Feature Selection

# %%
skip_columns = [
    'koi_disposition',
    'koi_fpflag_nt',
    'koi_fpflag_ss',
    'koi_fpflag_co',
    'koi_fpflag_ec'
]

keep_columns = [
    'koi_period',
    'koi_time0bk',
    'koi_impact',
    'koi_duration',
    'koi_depth',
    'koi_prad',
    'koi_teq',
    'koi_insol',
    'koi_model_snr',
    'koi_tce_plnt_num',
    'koi_steff',
    'koi_slogg',
    'koi_srad',
    'ra',
    'dec',
    'koi_kepmag'
]

features = exo2[keep_columns]
response = exo2[skip_columns]

# %% [markdown]
# ## Data Transformation

# %%
trans_data = pd.DataFrame()

for (col, data) in features.items():
    
    log_label = 'log_' + str(col)
    sq_label = 'sq_' + str(col)
    
    if col in skip_columns:
        continue    
        
    elif data.min() == 0:   
        trans_data[log_label] = np.log(exo2[col] + 0.001)
        
    elif data.max() == 0:
        trans_data[log_label] = np.log(np.absolute(exo2[col] + 0.001))
        
    else:
        trans_data[log_label] = np.log(exo2[col])

trans_data = trans_data.apply(zscore)

# %%
trans_data.sample(5)
# Out:
#       log_koi_period  log_koi_time0bk  log_koi_impact  log_koi_duration  \
# 5698       -1.027045        -0.606908        0.591834          0.436997
# 2023        0.317106         0.546458       -0.497003          0.038740
# 3929       -1.223774        -0.592775       -0.760178         -0.309623
# 6558        2.167583         1.197640       -0.245444          2.018868
# 3561        0.307279        -0.258232        0.884718          0.564376
#
#       log_koi_depth  log_koi_prad  log_koi_teq  log_koi_insol  \
# 5698      -1.265873     -0.708589     1.555625       1.554567
# 2023       0.903650      0.333940    -0.398132      -0.398793
# 3929      -1.580637     -1.362732     1.222593       1.223869
# 6558      -0.979871     -0.601571    -1.480200      -1.481450
# 3561      -0.600911      0.808190    -0.447550      -0.447057
#
#       log_koi_model_snr  log_koi_tce_plnt_num  log_koi_steff  log_koi_slogg  \
# 5698          -0.198399             -0.404330       1.363557      -0.516762
# 2023           1.588797              1.665741       0.165577       0.321597
# 3929          -0.796663             -0.404330       0.791751       0.134175
# 6558          -0.610859             -0.404330       0.636672      -0.497479
# 3561          -0.568405             -0.404330      -0.239583       0.222139
#
#       log_koi_srad    log_ra   log_dec  log_koi_kepmag
# 5698      0.963367  0.263787  0.368868       -1.062697
# 2023     -0.300043 -1.370186 -1.563433       -0.283046
# 3929     -0.042545 -0.185716 -0.307155       -0.767726
# 6558      0.825180  0.634239 -0.755224       -2.179289
# 3561     -0.381573 -2.318560  0.877817       -0.244301

# %%
trans_data.describe()
# Out:
#        log_koi_period  log_koi_time0bk  log_koi_impact  log_koi_duration  \
# count    6.991000e+03     6.991000e+03    6.991000e+03      6.991000e+03
# mean     3.413884e-16     1.130947e-16    1.334300e-16      5.193163e-16
# std      1.000072e+00     1.000072e+00    1.000072e+00      1.000072e+00
# min     -2.024931e+00    -9.278127e-01   -4.198894e+00     -4.192470e+00
# 25%     -7.680863e-01    -5.862795e-01   -3.834722e-01     -6.516436e-01
# 50%     -1.001538e-01    -4.793827e-01    3.360781e-01     -7.293749e-02
# 75%      6.303920e-01     2.923666e-01    6.978462e-01      5.747399e-01
# max      2.502303e+00     7.959380e+00    4.105433e+00      4.673290e+00
#
#        log_koi_depth  log_koi_prad   log_koi_teq  log_koi_insol  \
# count   6.991000e+03  6.991000e+03  6.991000e+03   6.991000e+03
# mean   -2.120874e-16  2.462786e-16 -9.093316e-17  -1.688123e-16
# std     1.000072e+00  1.000072e+00  1.000072e+00   1.000072e+00
# min    -1.961696e+00 -2.132920e+00 -3.277051e+00  -3.216497e+00
# 25%    -6.690421e-01 -7.173098e-01 -6.559389e-01  -6.559453e-01
# 50%    -2.582815e-01 -3.808373e-01  3.286329e-02   3.205476e-02
# 75%     2.837342e-01  7.790426e-01  6.948925e-01   6.945080e-01
# max     3.201419e+00  6.581083e+00  4.127049e+00   4.127486e+00
#
#        log_koi_model_snr  log_koi_tce_plnt_num  log_koi_steff  log_koi_slogg  \
# count       6.991000e+03          6.991000e+03   6.991000e+03   6.991000e+03
# mean       -1.232822e-16         -3.293842e-15  -5.702316e-15   1.407114e-15
# std         1.000072e+00          1.000072e+00   1.000072e+00   1.000072e+00
# min        -1.966092e+00         -4.043305e-01  -5.280248e+00  -2.854633e+01
# 25%        -7.297967e-01         -4.043305e-01  -4.459761e-01  -8.897811e-02
# 50%        -3.387002e-01         -4.043305e-01   1.387939e-01   2.435832e-01
# 75%         4.125382e-01         -4.043305e-01   5.566798e-01   3.944825e-01
# max         3.250936e+00          5.805885e+00   7.270778e+00   1.446224e+00
#
#        log_koi_srad        log_ra       log_dec  log_koi_kepmag
# count  6.991000e+03  6.991000e+03  6.991000e+03    6.991000e+03
# mean  -4.096637e-17 -2.014174e-14 -2.751768e-15   -1.729199e-15
# std    1.000072e+00  1.000072e+00  1.000072e+00    1.000072e+00
# min   -3.811776e+00 -2.607284e+00 -2.155579e+00   -7.068785e+00
# 25%   -5.305633e-01 -7.032806e-01 -8.265061e-01   -5.364296e-01
# 50%   -2.288884e-01  5.679779e-02  4.252009e-03    2.290241e-01
# 75%    2.664406e-01  8.000558e-01  8.163930e-01    7.529442e-01
# max    8.171204e+00  1.993940e+00  2.204852e+00    2.921743e+00

# %%
fig = plt.figure(figsize=(15, 12))

for i in range(1, len(trans_data.columns)):
    plt.subplot(9, 9, i)

    plt.hist(trans_data.iloc[:, i], bins=50, color='#3F5D7D')
    plt.xlabel(trans_data.columns[i])

plt.tight_layout()

# %%
fig = plt.figure(figsize=(15,60))

for i in range(1, len(trans_data.columns)):
    
    plt.subplot(20, 5, i)

    ax = sns.boxplot(response['koi_disposition'], trans_data.iloc[:, i])
    plt.xticks(rotation = 45)     

plt.tight_layout()

# %%
export = pd.concat([response, trans_data], axis=1)

# %%
export.sample(10)
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 2964       CANDIDATE              0              0              0
# 6978  FALSE POSITIVE              0              0              1
# 4830  FALSE POSITIVE              0              1              0
# 471   FALSE POSITIVE              0              1              0
# 454   FALSE POSITIVE              0              0              1
# 4660  FALSE POSITIVE              0              1              0
# 3641       CANDIDATE              0              0              0
# 3197       CANDIDATE              0              0              0
# 671   FALSE POSITIVE              0              1              0
# 4417  FALSE POSITIVE              1              0              0
#
#       koi_fpflag_ec  log_koi_period  log_koi_time0bk  log_koi_impact  \
# 2964              0       -0.791583        -0.574834       -2.039566
# 6978              1       -0.286462        -0.545986       -0.390753
# 4830              0        0.030373        -0.333959        0.764928
# 471               0        0.823957        -0.376320        0.767133
# 454               1       -0.154473        -0.376932        0.890926
# 4660              0        0.012929        -0.378490        0.962654
# 3641              0        0.183083        -0.392888       -0.778740
# 3197              0       -0.107316        -0.530083        0.569975
# 671               0       -1.327094        -0.532035        0.683564
# 4417              0        0.462280        -0.144323        0.470825
#
#       log_koi_duration  log_koi_depth  ...  log_koi_teq  log_koi_insol  \
# 2964         -1.032212      -0.610421  ...     0.781586       0.781490
# 6978         -0.276340      -0.607227  ...     1.655268       1.655261
# 4830         -0.728855       1.508289  ...    -0.341808      -0.340577
# 471           0.655103       0.938866  ...    -0.186715      -0.187507
# 454          -0.249033      -0.428665  ...     0.468799       0.468262
# 4660         -0.538033       0.625524  ...     0.273331       0.274050
# 3641          0.598471      -0.583154  ...    -0.130485      -0.130019
# 3197         -0.207177      -0.410169  ...    -0.365373      -0.365444
# 671          -0.949576       0.789289  ...     0.945313       0.945222
# 4417         -0.845941       0.230013  ...    -0.856165      -0.856940
#
#       log_koi_model_snr  log_koi_tce_plnt_num  log_koi_steff  log_koi_slogg  \
# 2964          -0.964936             -0.404330       0.747152       0.227864
# 6978          -0.807640             -0.404330      -1.108627      -3.460950
# 4830           1.654643             -0.404330      -0.445976       0.398662
# 471            1.432806             -0.404330       1.577464      -0.264367
# 454           -0.096453             -0.404330       0.369165      -0.373554
# 4660          -0.161203             -0.404330      -0.162768      -0.573341
# 3641          -0.744583              1.665741       0.198309       0.077288
# 3197          -0.807640             -0.404330      -0.779907       0.511844
# 671            0.728899             -0.404330      -0.207475       0.374942
# 4417          -1.058005             -0.404330      -0.832936       0.437537
#
#       log_koi_srad    log_ra   log_dec  log_koi_kepmag
# 2964     -0.101308  0.693191 -1.406969        0.923734
# 6978      4.000298  1.803557  0.227784       -1.946202
# 4830     -0.572059  0.890817  0.854383        0.263783
# 471       0.687907  0.810881  0.252130       -0.170816
# 454       0.637539  0.144932 -1.832812       -0.655135
# 4660      0.609827  1.059088  0.621248        0.090836
# 3641      0.009972 -1.751794  0.878102        0.794306
# 3197     -0.790303 -2.098077  0.923320        1.148428
# 671      -0.503479 -0.085186  1.109644        0.237214
# 4417     -0.794891 -0.035288 -0.010512        1.021916
#
# [10 rows x 21 columns]

# %%
export.to_csv('transformed_features.csv')

# %% [markdown]
# ## Sparse Matrix

# %%
qual = pd.DataFrame()

for (col, data) in trans_data.items():
    
    label = 'qual_' + str(col)
    
    qual[label] = pd.cut(data, 2, labels = ['lower', 'upper'])
    
qual = pd.get_dummies(qual)

# %%
qual.sample(10)

# %%
sparse = pd.concat([response, qual], axis=1)

# %%
sparse.sample(10)

# %%
sparse.to_csv('sparse.csv')
