# %%
# Data manipulation and visualization packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Pre-processing and setup functions
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.utils import to_categorical

# Algorithms
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Neural Network
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# Report and model validation
from sklearn.metrics import classification_report

# Model persistence
from joblib import dump, load

pd.set_option('display.max_columns', 500)

# %% [markdown]
# exo = pd.read_csv('Data/cumulative.csv')

# %% [markdown]
# exo.head()

# %% [markdown]
# exo.sample(15)

# %% [markdown]
# exo.info()

# %% [markdown]
# ### Load Data

# %%
exo2 = pd.read_csv('Data/exoplanet_data.csv')

# %%
exo2.sample(20)
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 5881  FALSE POSITIVE              1              0              0
# 6614  FALSE POSITIVE              1              0              0
# 779        CONFIRMED              0              0              0
# 6344  FALSE POSITIVE              0              1              0
# 4812       CANDIDATE              0              0              0
# 5157       CONFIRMED              0              0              0
# 5228  FALSE POSITIVE              0              1              0
# 1264       CONFIRMED              0              0              0
# 1809       CONFIRMED              0              0              0
# 5417       CANDIDATE              0              0              0
# 1723  FALSE POSITIVE              0              1              1
# 2454       CONFIRMED              0              0              0
# 3568  FALSE POSITIVE              0              1              1
# 2239       CONFIRMED              0              0              0
# 5896  FALSE POSITIVE              0              1              0
# 4999       CANDIDATE              0              0              0
# 816        CONFIRMED              0              0              0
# 1096       CONFIRMED              0              0              0
# 6323       CANDIDATE              0              0              0
# 5236  FALSE POSITIVE              1              0              0
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 5881              0    2.305097     1.070000e-06    -1.070000e-06
# 6614              0  362.858010     3.497000e-02    -3.497000e-02
# 779               0   15.866248     6.810000e-05    -6.810000e-05
# 6344              0   18.527824     5.600000e-07    -5.600000e-07
# 4812              0   54.595746     5.848000e-04    -5.848000e-04
# 5157              0   21.090791     1.467000e-04    -1.467000e-04
# 5228              0    3.319523     1.280000e-06    -1.280000e-06
# 1264              0    5.037280     1.570000e-05    -1.570000e-05
# 1809              0    3.300408     2.210000e-05    -2.210000e-05
# 5417              0    5.704593     4.440000e-05    -4.440000e-05
# 1723              1    1.572181     7.880000e-06    -7.880000e-06
# 2454              0   30.826104     2.079000e-04    -2.079000e-04
# 3568              1   31.973065     7.277000e-04    -7.277000e-04
# 2239              0    6.098556     2.540000e-05    -2.540000e-05
# 5896              0   15.066492     3.010000e-06    -3.010000e-06
# 4999              0  265.296170     1.548000e-02    -1.548000e-02
# 816               0   44.841117     2.781000e-04    -2.781000e-04
# 1096              0    4.612674     1.210000e-05    -1.210000e-05
# 6323              0    4.848472     1.690000e-05    -1.690000e-05
# 5236              0  455.274050     5.654000e-02    -5.654000e-02
#
#       koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  koi_impact  \
# 5881   133.705069          0.000369         -0.000369      1.2860
# 6614   152.610400          0.092800         -0.092800      0.6260
# 779    141.087340          0.003230         -0.003230      0.8580
# 6344   139.257607          0.000025         -0.000025      0.1710
# 4812   156.837640          0.008780         -0.008780      0.3320
# 5157   133.963160          0.005810         -0.005810      0.8320
# 5228   131.923046          0.000300         -0.000300      1.1620
# 1264   134.109400          0.002580         -0.002580      0.9600
# 1809   133.567230          0.006020         -0.006020      0.0080
# 5417   134.401020          0.006660         -0.006660      0.2850
# 1723   131.774560          0.004700         -0.004700      1.1490
# 2454   153.015030          0.005520         -0.005520      0.9430
# 3568   133.840900          0.017200         -0.017200      0.7160
#
#             dec  koi_kepmag
# 5881  48.410751      13.866
# 6614  49.577091      13.503
# 779   41.632717      11.049
# 6344  42.059158      12.893
# 4812  42.642189      13.670
# 5157  48.034931      14.223
# 5228  46.343552      15.101
# 1264  49.331020      12.189
# 1809  43.403271      13.749
# 5417  49.028610      14.572
# 1723  39.703911      13.157
# 2454  40.520901      14.985
# 3568  44.662861      14.545
# 2239  42.338718      12.498
# 5896  38.738979      14.213
# 4999  38.654228      14.424
# 816   40.616150      15.565
# 1096  37.682819      12.992
# 6323  48.195271      14.849
# 5236  45.663551      13.829

# %%
exo2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6991 entries, 0 to 6990
# Data columns (total 41 columns):
# koi_disposition      6991 non-null object
# koi_fpflag_nt        6991 non-null int64
# koi_fpflag_ss        6991 non-null int64
# koi_fpflag_co        6991 non-null int64
# koi_fpflag_ec        6991 non-null int64
# koi_period           6991 non-null float64
# koi_period_err1      6991 non-null float64
# koi_period_err2      6991 non-null float64
# koi_time0bk          6991 non-null float64
# koi_time0bk_err1     6991 non-null float64
# koi_time0bk_err2     6991 non-null float64
# koi_impact           6991 non-null float64
# koi_impact_err1      6991 non-null float64
# koi_impact_err2      6991 non-null float64
# koi_duration         6991 non-null float64
# koi_duration_err1    6991 non-null float64
# koi_duration_err2    6991 non-null float64
# koi_depth            6991 non-null float64
# koi_depth_err1       6991 non-null float64
# koi_depth_err2       6991 non-null float64
# koi_prad             6991 non-null float64
# koi_prad_err1        6991 non-null float64
# koi_prad_err2        6991 non-null float64
# koi_teq              6991 non-null int64
# koi_insol            6991 non-null float64
# koi_insol_err1       6991 non-null float64
# koi_insol_err2       6991 non-null float64
# koi_model_snr        6991 non-null float64
# koi_tce_plnt_num     6991 non-null int64
# koi_steff            6991 non-null int64
# koi_steff_err1       6991 non-null int64
# koi_steff_err2       6991 non-null int64
# koi_slogg            6991 non-null float64
# koi_slogg_err1       6991 non-null float64
# koi_slogg_err2       6991 non-null float64
# koi_srad             6991 non-null float64
# koi_srad_err1        6991 non-null float64
# koi_srad_err2        6991 non-null float64
# ra                   6991 non-null float64
# dec                  6991 non-null float64
# koi_kepmag           6991 non-null float64
# dtypes: float64(31), int64(9), object(1)
# memory usage: 2.2+ MB

# %%
#exo2['koi_disposition']

# %% [markdown]
# ## Separate X and y

# %%
y = exo2['koi_disposition']
exo2_features = exo2.drop(['koi_disposition'], axis=1)

# %%
#exo2_features.sample(15)

# %% [markdown]
# ## Pre-processing (Scaling)

# %%
scaler = MinMaxScaler()

scaled_features = scaler.fit_transform(exo2_features)

# %% [markdown]
# ## Train, Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features, y, random_state=42, stratify=y)

# %% [markdown]
# ## Parameters

# %%
# SVM
svm = SVC(kernel = 'linear')
svm_grid = {'C': [1, 5, 10],
              'gamma': [0.001, 0.001, 0.01]}

# Random Forest
forest = RandomForestClassifier()
forest_grid = {
    'n_estimators': [25, 50, 100, 200, 400, 800],
    'criterion': ['gini', 'entropy'],
    'bootstrap': [True, False]
}

# %% [markdown]
# ## SVM

# %%
grid = GridSearchCV(svm, svm_grid, verbose=3)
grid.fit(X_train, y_train)

# %%
print(grid.best_params_)

# %%
print(grid.best_score_)

# %%
predictions = grid.predict(X_test)
print(classification_report(y_test, predictions))

# %% [markdown]
# ## Random Forest

# %%
grid = GridSearchCV(
    forest, 
    forest_grid, 
    scoring='accuracy', 
    cv=10, 
    n_jobs=-1, 
    verbose=3
)

grid.fit(X_train, y_train)

# %%
print(grid.best_params_)

# %%
print(grid.best_score_)

# %%
predictions = grid.predict(X_test)
print(classification_report(y_test, predictions))

# %% [markdown]
# ## GBM

# %%
gbm_search = GradientBoostingClassifier()

gbm_grid = {
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [25, 50, 100, 200, 400],
    'max_depth': [1, 2, 3, 4, 5]
}

grid = GridSearchCV(
    gbm_search,
    gbm_grid,
    scoring='accuracy',
    cv=5,
    verbose=3,
    n_jobs=-1
)

# %%
grid.fit(X_train, y_train)

# %%
print(grid.best_params_)

# %%
print(grid.best_score_)

# %%
predictions = grid.predict(X_test)
print(classification_report(y_test, predictions))

# %% [markdown]
# ### Selected Parameter GBM

# %%
gbm_final = GradientBoostingClassifier(
    learning_rate = 0.1, 
    max_depth = 4, 
    n_estimators = 400,
    verbose = 3
)

gbm_final.fit(X_train, y_train)

# %%
predictions = grid.predict(X_test)
print(classification_report(y_test, predictions))

# %%
predictions

# %%
feature_importances = pd.Series(gbm_final.feature_importances_, index = exo2_features.columns)
feature_importances[:15].sort_values(ascending=False)

# %%
#dump(gbm_final, 'gbm_model_exoplanet.joblib')

# %% [markdown]
# ## Deep Neural Network

# %%
y = exo2['koi_disposition']
X = exo2.drop(['koi_disposition'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)
# Out:
# C:\Users\TPCal\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
X_train_scaled.shape, y_train_categorical.shape
# Out:
# ((5243, 40), (5243, 3))

# %%
model = Sequential()
model.add(Dense(units=10, activation='relu', input_dim=40))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=3, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\TPCal\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                410
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 553
# Trainable params: 553
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

model.fit(
    X_train_scaled, 
    y_train_categorical, 
    epochs=100, 
    shuffle=True, 
    verbose=2
)
# Out:
# WARNING:tensorflow:From C:\Users\TPCal\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
#  - 0s - loss: 0.9822 - acc: 0.5010
# Epoch 2/100
#  - 0s - loss: 0.7418 - acc: 0.5211
# Epoch 3/100
#  - 0s - loss: 0.5824 - acc: 0.7366
# Epoch 4/100
#  - 0s - loss: 0.5251 - acc: 0.7917
# Epoch 5/100
#  - 0s - loss: 0.4939 - acc: 0.7904
# Epoch 6/100
#  - 0s - loss: 0.4731 - acc: 0.7932
# Epoch 7/100
#  - 0s - loss: 0.4572 - acc: 0.7967
# Epoch 8/100
#  - 0s - loss: 0.4446 - acc: 0.8104
# Epoch 9/100
#  - 0s - loss: 0.4331 - acc: 0.8144
# Epoch 10/100
#  - 0s - loss: 0.4238 - acc: 0.8205
# Epoch 11/100
#  - 0s - loss: 0.4149 - acc: 0.8259
# Epoch 12/100
#  - 0s - loss: 0.4057 - acc: 0.8293
# Epoch 13/100
#  - 0s - loss: 0.3982 - acc: 0.8282
# Epoch 14/100
#  - 0s - loss: 0.3907 - acc: 0.8339
# Epoch 15/100
#  - 0s - loss: 0.3829 - acc: 0.8379
# Epoch 16/100
#  - 0s - loss: 0.3778 - acc: 0.8282
# Epoch 17/100
#  - 0s - loss: 0.3722 - acc: 0.8354
# Epoch 18/100
#  - 0s - loss: 0.3666 - acc: 0.8365
#  - 0s - loss: 0.2931 - acc: 0.8703
# Epoch 64/100
#  - 0s - loss: 0.2957 - acc: 0.8665
# Epoch 65/100
#  - 0s - loss: 0.2936 - acc: 0.8669
# Epoch 66/100
#  - 0s - loss: 0.2949 - acc: 0.8669
# Epoch 67/100
#  - 0s - loss: 0.2917 - acc: 0.8695
# Epoch 68/100
#  - 0s - loss: 0.2920 - acc: 0.8716
# Epoch 69/100
#  - 0s - loss: 0.2918 - acc: 0.8699
# Epoch 70/100
#  - 0s - loss: 0.2902 - acc: 0.8730
# Epoch 71/100
#  - 0s - loss: 0.2887 - acc: 0.8730
# Epoch 72/100
#  - 0s - loss: 0.2891 - acc: 0.8713
# Epoch 73/100
#  - 0s - loss: 0.2888 - acc: 0.8701
# Epoch 74/100
#  - 0s - loss: 0.2862 - acc: 0.8743
# Epoch 75/100
#  - 0s - loss: 0.2864 - acc: 0.8755
# Epoch 76/100
#  - 0s - loss: 0.2866 - acc: 0.8741
# Epoch 77/100
#  - 0s - loss: 0.2891 - acc: 0.8741
# Epoch 78/100
#  - 0s - loss: 0.2868 - acc: 0.8764
# Epoch 79/100
#  - 0s - loss: 0.2854 - acc: 0.8739
# Epoch 80/100
#  - 0s - loss: 0.2852 - acc: 0.8760
# Epoch 81/100
#  - 0s - loss: 0.2833 - acc: 0.8760
# Epoch 82/100
#  - 0s - loss: 0.2835 - acc: 0.8755
# Epoch 83/100
#  - 0s - loss: 0.2832 - acc: 0.8730
# Epoch 84/100
#  - 0s - loss: 0.2842 - acc: 0.8718
# Epoch 85/100
#  - 0s - loss: 0.2835 - acc: 0.8739
# Epoch 86/100
#  - 0s - loss: 0.2815 - acc: 0.8760
# Epoch 87/100
#  - 0s - loss: 0.2828 - acc: 0.8728
# Epoch 88/100
#  - 0s - loss: 0.2807 - acc: 0.8753
# Epoch 89/100
#  - 0s - loss: 0.2826 - acc: 0.8789
# Epoch 90/100
#  - 0s - loss: 0.2819 - acc: 0.8766
# Epoch 91/100
#  - 0s - loss: 0.2780 - acc: 0.8766
# Epoch 92/100
#  - 0s - loss: 0.2807 - acc: 0.8764
# Epoch 93/100
#  - 0s - loss: 0.2783 - acc: 0.8774
# Epoch 94/100
#  - 0s - loss: 0.2803 - acc: 0.8756
# Epoch 95/100
#  - 0s - loss: 0.2806 - acc: 0.8760
# Epoch 96/100
#  - 0s - loss: 0.2821 - acc: 0.8766
# Epoch 97/100
#  - 0s - loss: 0.2771 - acc: 0.8795
# Epoch 98/100
#  - 0s - loss: 0.2768 - acc: 0.8796
# Epoch 99/100
#  - 0s - loss: 0.2778 - acc: 0.8808
# Epoch 100/100
#  - 0s - loss: 0.2785 - acc: 0.8741

# %%
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
#  - 0s - loss: 0.2978 - acc: 0.8839
# Normal Neural Network - Loss: 0.2978257047911803, Accuracy: 0.8838672637939453

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:10])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

print(f'Predicted classes: {prediction_labels}')
print(f'Actual labels: {list(y_test[:10])}')
# Out:
# Predicted classes: ['CANDIDATE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CANDIDATE'
#  'FALSE POSITIVE' 'CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE'
#  'CONFIRMED' 'FALSE POSITIVE']
# Actual labels: ['CANDIDATE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CONFIRMED']
